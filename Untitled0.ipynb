# %% [markdown]
# <a href="https://colab.research.google.com/github/martinagonz/EVweb2/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# Preprocesado y modelado
# ==============================================================================
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
    name=fn
df = pd.read_csv(name, sep=",")
df.head(10)
# Out:
#      <input type="file" id="files-6b84dd1e-a809-4a14-a6aa-162d01a16f02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b84dd1e-a809-4a14-a6aa-162d01a16f02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
corr_test = pearsonr(x = df['Attack'], y =  df['Defense']) # Changed 'datos' to 'df'
print("Coeficiente de correlación de Pearson: ", corr_test[0])
print("P-value: ", corr_test[1])
# Out:
# Coeficiente de correlación de Pearson:  0.4386870551184896
# P-value:  5.8584798642891506e-39

# %%
# División de los datos en train y test
# ==============================================================================
X = df[['Attack']]
y = df['Defense']

X_train, X_test, y_train, y_test = train_test_split(
                                        X.values.reshape(-1,1),
                                        y.values.reshape(-1,1),
                                        train_size   = 0.8,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# Creación del modelo
# ==============================================================================
modelo = LinearRegression()
modelo.fit(X = X_train.reshape(-1, 1), y = y_train)
# Out:
# LinearRegression()

# %%
# Información del modelo
# ==============================================================================
print("Intercept:", modelo.intercept_)
print("Coeficiente:", list(zip(X.columns, modelo.coef_.flatten(), )))
print("Coeficiente de determinación R^2:", modelo.score(X, y))
# Out:
# Intercept: [38.96930181]
# Coeficiente: [('Attack', np.float64(0.44420496760830086))]
# Coeficiente de determinación R^2: 0.19183671768421162
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
df[['Attack','Defense']].corr()
# Out:
#            Attack   Defense
# Attack   1.000000  0.438687
# Defense  0.438687  1.000000

# %%
df[['Attack','Defense']].corr('spearman')
# Out:
#            Attack   Defense
# Attack   1.000000  0.514995
# Defense  0.514995  1.000000

# %% [markdown]
# regreciones lineales

# %%
# Gráfico
# ==============================================================================
fig, ax = plt.subplots(figsize=(6, 3.84))

df.plot(
    x    = 'Attack',
    y    = 'Defense',
    c    = 'firebrick',
    kind = "scatter",
    ax   = ax
)
ax.set_title('Distribución de ataques y defensa');

# %%
stats = ['HP', 'Attack', 'Defense', 'Speed', 'Sp. Atk', 'Sp. Def'] # Changed column names
df_stats = df[stats]
c = df_stats.corr()
plt.figure(figsize=(10, 5))
sns.heatmap(c, cmap="BrBG", annot=True, fmt=".2f", linewidths=0.5)

# Título del gráfico
plt.title("Matriz de Correlación de Estadísticas de Pokémon")

# Mostrar el gráfico
plt.show()

# Mostrar la matriz de correlación en consola
print(c)
# Out:
#                HP    Attack   Defense     Speed   Sp. Atk   Sp. Def
# HP       1.000000  0.422386  0.239622  0.175952  0.362380  0.378718
# Attack   0.422386  1.000000  0.438687  0.381240  0.396362  0.263990
# Defense  0.239622  0.438687  1.000000  0.015227  0.223549  0.510747
# Speed    0.175952  0.381240  0.015227  1.000000  0.473018  0.259133
# Sp. Atk  0.362380  0.396362  0.223549  0.473018  1.000000  0.506121
# Sp. Def  0.378718  0.263990  0.510747  0.259133  0.506121  1.000000

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Crear el gráfico de dispersión entre HP y Speed
ax.scatter(df['Attack'], df['Defense'], alpha=0.7, edgecolors='k')

# Etiquetas de los ejes
ax.set_xlabel('Attack')
ax.set_ylabel('Defense')

# Título del gráfico
ax.set_title('Relación entre Ataque y Defensa en Pokémon')

# Mostrar el gráfico
plt.show()

# %%
# Grafiquemos la regresión

fig, ax = plt.subplots(figsize=(6, 3.84))

df.plot(
    x    = 'Attack',
    y    = 'Defense',
    c    = 'firebrick',
    kind = "scatter",
    ax   = ax
)
ax.set_title('blablabla');

y_pred = modelo.predict(X_train)

plt.plot(X_train[:,0],  y_pred, color='blue', linewidth=3)

plt.xlabel('Attack')
plt.ylabel('Defense')
plt.title('Regresión Lineal')

plt.show()
